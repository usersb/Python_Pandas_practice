# %% [markdown]
# **Using Seaborn to visualize a Pandas Dataframe**
#
# https://chrisalbon.com/python/data_wrangling/pandas_with_seaborn/

# %%
import pandas as pd
import random

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.DataFrame()

df['x'] = random.sample(range(1,100),25)
df['y'] = random.sample(range(1,100),25)

df.head()
# Out:
#     x   y
# 0  47  43
# 1  98  21
# 2  81  71
# 3  70  59
# 4  60  17

# %% [markdown]
# **Scatter Plot**

# %%
sns.lmplot('x','y',data=df,fit_reg=False)

# %% [markdown]
# **Density Plot**

# %%
sns.kdeplot(df.y)
# Out:
# /Users/Sonal/anaconda/envs/py35/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.kdeplot(df.y,df.x)

# %%
sns.distplot(df.x)
# Out:
# /Users/Sonal/anaconda/envs/py35/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# **Histogram**

# %%
plt.hist(df.x, alpha =0.3)
sns.rugplot(df.x)

# %% [markdown]
# **Boxplot**

# %%
sns.boxplot([df.y,df.x])

# %% [markdown]
# **Violinplot**

# %%
sns.violinplot([df.y,df.x])

# %% [markdown]
# **Heatmap**

# %%
sns.heatmap([df.y,df.x],annot=True,fmt='d')

# %% [markdown]
# **Clustermap**

# %%
sns.clustermap(df)
# Out:
# /Users/Sonal/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
